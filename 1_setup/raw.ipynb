# %%
# %sql
USE CATALOG shopvista;

CREATE SCHEMA IF NOT EXISTS raw;

CREATE EXTERNAL VOLUME IF NOT EXISTS raw.raw_landing
    LOCATION 'abfss://shopvista-raw-data@storageshopvista.dfs.core.windows.net/'
    COMMENT 'This is the landing zone for shopvista data';
