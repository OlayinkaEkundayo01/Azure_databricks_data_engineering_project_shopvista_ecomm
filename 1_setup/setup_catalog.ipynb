# %%
# %sql
-- Create Shopvista Catalog (Managed Location)
CREATE CATALOG IF NOT EXISTS Shopvista
MANAGED LOCATION 'abfss://uc-catalog@storageshopvista.dfs.core.windows.net/shopvista-catalog'
COMMENT 'Shopvista Project Catalog backed by external location'

# %%
# %sql
-- Use Shopvista Catalog
USE catalog shopvista

# %%
# %sql
-- Create schema
CREATE SCHEMA IF NOT EXISTS Shopvista.gold;
CREATE SCHEMA IF NOT EXISTS Shopvista.silver;
CREATE SCHEMA IF NOT EXISTS Shopvista.bronze;
